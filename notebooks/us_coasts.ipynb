# %% [markdown]
# # CONUS Coasts

# %% [markdown]
# ### US States and Coastlines
#
# **Census TIGER (Topologically Integrated Geographic Encoding and Referencing database)**

# %%
from __future__ import annotations

import warnings
from pathlib import Path

import geopandas as gpd

warnings.filterwarnings("ignore", message=".*initial implementation of Parquet.*")
root = Path("input_data")
root.mkdir(exist_ok=True)
BASE_PLOT = {"facecolor": "k", "edgecolor": "b", "alpha": 0.2, "figsize": (12, 6)}
CRS = "epsg:5070"


def tiger_shp_2022(data):
    url = f"https://www2.census.gov/geo/tiger/TIGER2022/{data.upper()}/tl_2022_us_{data}.zip"
    return gpd.read_file(url)


cfile = Path(root, "us_state.feather")
if cfile.exists():
    state = gpd.read_feather(cfile)
else:
    state = tiger_shp_2022("state")
    state.to_feather(cfile)

# %%
ax = state.to_crs(CRS).plot(**BASE_PLOT)
ax.axis("off")
ax.margins(0)

# %%
cfile = Path(root, "us_coastline.feather")
if cfile.exists():
    coastline = gpd.read_feather(cfile)
else:
    coastline = tiger_shp_2022("coastline")
    coastline.to_feather(cfile)

# %%
ax = coastline.to_crs(CRS).plot(figsize=(12, 6))
ax.axis("off")
ax.margins(0)

# %% [markdown]
# ### Clip to CONUS

# %%
from shapely.geometry import box

conus_bounds = box(-125, 24, -65, 50)

cfile = Path(root, "conus_states.feather")
if cfile.exists():
    conus_states = gpd.read_feather(cfile)
else:
    conus_states = state[state.within(conus_bounds)]
    conus_states.to_feather(cfile)

# %%
ax = conus_states.to_crs(CRS).plot(**BASE_PLOT)
ax.axis("off")
ax.margins(0)

# %%
conus_coastline = coastline[coastline.within(conus_bounds)]

cfile = Path(root, "us_coast_states.feather")
if cfile.exists():
    coast_states = gpd.read_feather(cfile)
else:
    coast_states = state[state.intersects(conus_coastline.union_all)]
    coast_states.to_feather(cfile)

# %%
ax = coast_states.to_crs(CRS).plot(**BASE_PLOT)
conus_coastline.to_crs(CRS).plot(ax=ax, edgecolor="b", lw=2, zorder=1)
ax.axis("off")
ax.margins(0)

# %% [markdown]
# ### Tidal and Estuary USGS stations
#
# <img src="https://raw.githubusercontent.com/cheginit/HyRiver-examples/main/notebooks/_static/pygeohydro_logo.png" width="400"/>

# %% [markdown]
# We need to look at the [Water Services](https://waterservices.usgs.gov/rest/Site-Service.html) API.

# %%
import pandas as pd

from pygeohydro import NWIS
from pygeohydro.exceptions import ZeroMatchedError

cfile = Path(root, "coast_stations.feather")
if cfile.exists():
    coast_stations = gpd.read_feather(cfile)
else:
    queries = [
        {
            "stateCd": s.lower(),
            "siteType": "ST-TS,ES",
            "hasDataTypeCd": "dv",
            "outputDataTypeCd": "dv",
        }
        for s in coast_states.STUSPS
    ]
    nwis = NWIS()

    def get_info(q):
        try:
            return nwis.get_info(q, True)
        except ZeroMatchedError:
            return None

    sites = pd.concat(get_info(q) for q in queries if q is not None)

    coast_stations = gpd.GeoDataFrame(
        sites,
        geometry=gpd.points_from_xy(sites.dec_long_va, sites.dec_lat_va),
        crs="epsg:4269",
    )
    coast_stations.to_feather(cfile)

st = coast_stations[["site_no", "site_tp_cd", "geometry"]].to_crs(CRS)
ts = st[st.site_tp_cd == "ST-TS"].drop_duplicates()
es = st[st.site_tp_cd == "ES"].drop_duplicates()

# %%
ax = conus_states.to_crs(CRS).plot(**BASE_PLOT)
coastline[coastline.within(conus_bounds)].to_crs(CRS).plot(ax=ax, edgecolor="g", lw=2, zorder=1)
ts.plot(ax=ax, lw=3, c="r")
es.plot(ax=ax, lw=3, c="b")
ax.legend(["Coastline", f"ST-TS ({ts.shape[0]})", f"ES ({es.shape[0]})"], loc="best")
ax.axis("off")
ax.margins(0)
ax.figure.savefig(Path("_static", "us_coasts.png"), dpi=300, bbox_inches="tight", facecolor="w")

# %% [markdown]
# ### Mean daily discharge for all stations

# %%
import numpy as np
import pandas as pd

cfile = Path(root, "discharge.parquet")
dates = ("2000-01-01", "2015-12-31")

if cfile.exists():
    discharge = pd.read_parquet(cfile)
else:
    nwis = NWIS()
    discharge = nwis.get_streamflow(
        coast_stations.site_no,
        dates,
    )
    discharge[discharge < 0] = np.nan
    discharge.to_parquet(cfile)

# %%
ax = discharge.plot(legend=False, lw=0.8, figsize=(7, 3.5))
ax.set_ylabel("Q (cms)")
ax.set_xlabel("")
ax.margins(x=0)

# %% [markdown]
# Let's find the station that has the largest peak value and see it on a map.

# %%
station_id = discharge.max().idxmax().split("-")[1]

coast_stations[coast_stations.site_no == station_id].iloc[0]["station_nm"]
# Out:
# 'COLUMBIA RIVER AT PORT WESTWARD, NEAR QUINCY, OR'

# %%
import pygeohydro as gh

lat, lon = coast_stations[coast_stations.site_no == station_id].iloc[0][
    ["dec_lat_va", "dec_long_va"]
]
bbox = (lon - 0.2, lat - 0.2, lon + 0.2, lat + 0.2)
nwis_kwds = {"hasDataTypeCd": "dv", "outputDataTypeCd": "dv", "parameterCd": "00060"}

station_map = gh.interactive_map(bbox, nwis_kwds=nwis_kwds)

# %%
station_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_447df98212b5805b031c8f27ab7d2a56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_447df98212b5805b031c8f27ab7d2a56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_447df98212b5805b031c8f27ab7d2a56 = L.map(
#                 &quot;map_447df98212b5805b031c8f27ab7d2a56&quot;,
#                 {
#                     center: [46.18122136, -123.1834539],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78768865b2e40337a6f9b1f24e63ae6b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78768865b2e40337a6f9b1f24e63ae6b.addTo(map_447df98212b5805b031c8f27ab7d2a56);
#
#
#             var marker_d93f35c25416b3992b13c7931bc57948 = L.marker(
#                 [46.2026102, -123.1553978],
#                 {
# }
#             ).addTo(map_447df98212b5805b031c8f27ab7d2a56);
#
#
#             var icon_7a718c54cbb009e42f6de007958126c7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d93f35c25416b3992b13c7931bc57948.setIcon(icon_7a718c54cbb009e42f6de007958126c7);
#
#
#         var popup_cec86173c1226d7f46e73732ea75f34d = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_c35496e5938c9c9abe1d299bebe3aa47 = $(`&lt;div id=&quot;html_c35496e5938c9c9abe1d299bebe3aa47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Site No.&lt;/strong&gt;: 14246000&lt;br&gt;&lt;strong&gt;Station Name&lt;/strong&gt;: Abernathy Creek Near Longview, WA&lt;br&gt;&lt;strong&gt;Coordinate&lt;/strong&gt;: (-123.1553978, 46.2026102)&lt;br&gt;&lt;strong&gt;Altitude&lt;/strong&gt;: 70.0 ft above NGVD29&lt;br&gt;&lt;strong&gt;HUC8&lt;/strong&gt;: 17080003&lt;br&gt;&lt;strong&gt;Drainage Area (NWIS)&lt;/strong&gt;: 20.3 sqmi&lt;br&gt;&lt;strong&gt;Contributing Drainage Area (NWIS)&lt;/strong&gt;: N/A&lt;br&gt;&lt;strong&gt;Drainage Area (GagesII)&lt;/strong&gt;: 53.4384 sqkm&lt;br&gt;&lt;strong&gt;HCDN 2009&lt;/strong&gt;: False&lt;br&gt;&lt;a href=&quot;https://waterdata.usgs.gov/nwis/inventory?agency_code=USGS&amp;site_no=14246000&quot; target=&quot;_blank&quot;&gt;More on USGS Website&lt;/div&gt;`)[0];
#                 popup_cec86173c1226d7f46e73732ea75f34d.setContent(html_c35496e5938c9c9abe1d299bebe3aa47);
#
#
#
#         marker_d93f35c25416b3992b13c7931bc57948.bindPopup(popup_cec86173c1226d7f46e73732ea75f34d)
#         ;
#
#
#
#
#             var marker_0241729f654ebd74292817f1f9e689d3 = L.marker(
#                 [46.19427678, -123.19151],
#                 {
# }
#             ).addTo(map_447df98212b5805b031c8f27ab7d2a56);
#
#
#             var icon_aeca8bfe129f55b27115679ef3f66e98 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0241729f654ebd74292817f1f9e689d3.setIcon(icon_aeca8bfe129f55b27115679ef3f66e98);
#
#
#         var popup_0a37142f76579bbe174313f5ce2d72f1 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_7a3494e29b9aeaf42f5546e557ccdf59 = $(`&lt;div id=&quot;html_7a3494e29b9aeaf42f5546e557ccdf59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Site No.&lt;/strong&gt;: 14246500&lt;br&gt;&lt;strong&gt;Station Name&lt;/strong&gt;: Mill Creek Near Cathlamet, WA&lt;br&gt;&lt;strong&gt;Coordinate&lt;/strong&gt;: (-123.19151, 46.19427678)&lt;br&gt;&lt;strong&gt;Altitude&lt;/strong&gt;: 70.0 ft above NGVD29&lt;br&gt;&lt;strong&gt;HUC8&lt;/strong&gt;: 17080003&lt;br&gt;&lt;strong&gt;Drainage Area (NWIS)&lt;/strong&gt;: 27.6 sqmi&lt;br&gt;&lt;strong&gt;Contributing Drainage Area (NWIS)&lt;/strong&gt;: N/A&lt;br&gt;&lt;strong&gt;Drainage Area (GagesII)&lt;/strong&gt;: 75.5847 sqkm&lt;br&gt;&lt;strong&gt;HCDN 2009&lt;/strong&gt;: False&lt;br&gt;&lt;a href=&quot;https://waterdata.usgs.gov/nwis/inventory?agency_code=USGS&amp;site_no=14246500&quot; target=&quot;_blank&quot;&gt;More on USGS Website&lt;/div&gt;`)[0];
#                 popup_0a37142f76579bbe174313f5ce2d72f1.setContent(html_7a3494e29b9aeaf42f5546e557ccdf59);
#
#
#
#         marker_0241729f654ebd74292817f1f9e689d3.bindPopup(popup_0a37142f76579bbe174313f5ce2d72f1)
#         ;
#
#
#
#
#             var marker_88e3bfc17d76313216bd3951958a275d = L.marker(
#                 [46.18122136, -123

# %% [markdown]
# ### River network data
#
# <img src="https://raw.githubusercontent.com/cheginit/HyRiver-examples/main/notebooks/_static/pynhd_logo.png" width="400"/>

# %% [markdown]
# #### Basin

# %%
import pynhd as nhd

nldi = nhd.NLDI()
cfile = Path(root, "basin.feather")
if cfile.exists():
    basin = gpd.read_feather(cfile)
else:
    basin = nldi.get_basins(station_id)
    basin.to_feather(cfile)

# %%
ax = basin.to_crs(CRS).plot(**BASE_PLOT)
ax.axis("off")
ax.margins(0)

# %%
import folium

folium.GeoJson(basin.geometry).add_to(station_map)
station_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_447df98212b5805b031c8f27ab7d2a56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_447df98212b5805b031c8f27ab7d2a56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_447df98212b5805b031c8f27ab7d2a56 = L.map(
#                 &quot;map_447df98212b5805b031c8f27ab7d2a56&quot;,
#                 {
#                     center: [46.18122136, -123.1834539],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78768865b2e40337a6f9b1f24e63ae6b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78768865b2e40337a6f9b1f24e63ae6b.addTo(map_447df98212b5805b031c8f27ab7d2a56);
#
#
#             var marker_d93f35c25416b3992b13c7931bc57948 = L.marker(
#                 [46.2026102, -123.1553978],
#                 {
# }
#             ).addTo(map_447df98212b5805b031c8f27ab7d2a56);
#
#
#             var icon_7a718c54cbb009e42f6de007958126c7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d93f35c25416b3992b13c7931bc57948.setIcon(icon_7a718c54cbb009e42f6de007958126c7);
#
#
#         var popup_cec86173c1226d7f46e73732ea75f34d = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_c35496e5938c9c9abe1d299bebe3aa47 = $(`&lt;div id=&quot;html_c35496e5938c9c9abe1d299bebe3aa47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Site No.&lt;/strong&gt;: 14246000&lt;br&gt;&lt;strong&gt;Station Name&lt;/strong&gt;: Abernathy Creek Near Longview, WA&lt;br&gt;&lt;strong&gt;Coordinate&lt;/strong&gt;: (-123.1553978, 46.2026102)&lt;br&gt;&lt;strong&gt;Altitude&lt;/strong&gt;: 70.0 ft above NGVD29&lt;br&gt;&lt;strong&gt;HUC8&lt;/strong&gt;: 17080003&lt;br&gt;&lt;strong&gt;Drainage Area (NWIS)&lt;/strong&gt;: 20.3 sqmi&lt;br&gt;&lt;strong&gt;Contributing Drainage Area (NWIS)&lt;/strong&gt;: N/A&lt;br&gt;&lt;strong&gt;Drainage Area (GagesII)&lt;/strong&gt;: 53.4384 sqkm&lt;br&gt;&lt;strong&gt;HCDN 2009&lt;/strong&gt;: False&lt;br&gt;&lt;a href=&quot;https://waterdata.usgs.gov/nwis/inventory?agency_code=USGS&amp;site_no=14246000&quot; target=&quot;_blank&quot;&gt;More on USGS Website&lt;/div&gt;`)[0];
#                 popup_cec86173c1226d7f46e73732ea75f34d.setContent(html_c35496e5938c9c9abe1d299bebe3aa47);
#
#
#
#         marker_d93f35c25416b3992b13c7931bc57948.bindPopup(popup_cec86173c1226d7f46e73732ea75f34d)
#         ;
#
#
#
#
#             var marker_0241729f654ebd74292817f1f9e689d3 = L.marker(
#                 [46.19427678, -123.19151],
#                 {
# }
#             ).addTo(map_447df98212b5805b031c8f27ab7d2a56);
#
#
#             var icon_aeca8bfe129f55b27115679ef3f66e98 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0241729f654ebd74292817f1f9e689d3.setIcon(icon_aeca8bfe129f55b27115679ef3f66e98);
#
#
#         var popup_0a37142f76579bbe174313f5ce2d72f1 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_7a3494e29b9aeaf42f5546e557ccdf59 = $(`&lt;div id=&quot;html_7a3494e29b9aeaf42f5546e557ccdf59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Site No.&lt;/strong&gt;: 14246500&lt;br&gt;&lt;strong&gt;Station Name&lt;/strong&gt;: Mill Creek Near Cathlamet, WA&lt;br&gt;&lt;strong&gt;Coordinate&lt;/strong&gt;: (-123.19151, 46.19427678)&lt;br&gt;&lt;strong&gt;Altitude&lt;/strong&gt;: 70.0 ft above NGVD29&lt;br&gt;&lt;strong&gt;HUC8&lt;/strong&gt;: 17080003&lt;br&gt;&lt;strong&gt;Drainage Area (NWIS)&lt;/strong&gt;: 27.6 sqmi&lt;br&gt;&lt;strong&gt;Contributing Drainage Area (NWIS)&lt;/strong&gt;: N/A&lt;br&gt;&lt;strong&gt;Drainage Area (GagesII)&lt;/strong&gt;: 75.5847 sqkm&lt;br&gt;&lt;strong&gt;HCDN 2009&lt;/strong&gt;: False&lt;br&gt;&lt;a href=&quot;https://waterdata.usgs.gov/nwis/inventory?agency_code=USGS&amp;site_no=14246500&quot; target=&quot;_blank&quot;&gt;More on USGS Website&lt;/div&gt;`)[0];
#                 popup_0a37142f76579bbe174313f5ce2d72f1.setContent(html_7a3494e29b9aeaf42f5546e557ccdf59);
#
#
#
#         marker_0241729f654ebd74292817f1f9e689d3.bindPopup(popup_0a37142f76579bbe174313f5ce2d72f1)
#         ;
#
#
#
#
#             var marker_88e3bfc17d76313216bd3951958a275d = L.marker(
#                 [46.18122136, -123

# %% [markdown]
# #### Main river network

# %%
cfile = Path(root, "flowline_main.feather")
if cfile.exists():
    flw_main = gpd.read_feather(cfile)
else:
    flw_main = nldi.navigate_byid(
        fsource="nwissite",
        fid=f"USGS-{station_id}",
        navigation="upstreamMain",
        source="flowlines",
        distance=4000,
    )
    flw_main.to_feather(cfile)

# %% [markdown]
# #### Tributaries

# %%
cfile = Path(root, "flowline_trib.feather")
if cfile.exists():
    flw_trib = gpd.read_feather(cfile)
else:
    flw_trib = nldi.navigate_byid(
        fsource="nwissite",
        fid=f"USGS-{station_id}",
        navigation="upstreamTributaries",
        source="flowlines",
        distance=4000,
    )
    flw_trib.to_feather(cfile)
flw_trib["nhdplus_comid"] = flw_trib["nhdplus_comid"].astype("float").astype("Int64")

# %%
BASE_PLOT["figsize"] = (8, 5)
ax = basin.plot(**BASE_PLOT)
flw_trib.plot(ax=ax)
flw_main.plot(ax=ax, lw=3, color="r")
ax.legend(["Tributaries", "Main"])
ax.axis("off")
ax.margins(0)

# %% [markdown]
# #### NHDPlus Value Added Attributes (VAA)

# %%
cfile = Path(root, "nhdplus_vaa.parquet")
nhdplus_vaa = nhd.nhdplus_vaa(cfile)

flw_trib = flw_trib.merge(nhdplus_vaa, left_on="nhdplus_comid", right_on="comid", how="left")
flw_trib.loc[flw_trib.slope < 0, "slope"] = np.nan

# %%
ax = basin.plot(**BASE_PLOT)
flw_trib.plot(
    ax=ax,
    column="slope",
    scheme="natural_breaks",
    k=6,
    cmap="plasma",
    legend=True,
    legend_kwds={"title": "Slope [-]"},
)
ax.axis("off")
ax.margins(0)
