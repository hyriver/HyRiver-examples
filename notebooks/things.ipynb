# %% [markdown]
# # SensorThings

# %%
from __future__ import annotations

from pygeohydro import SensorThings

# %% [markdown]
# SensorThings is a recently released USGS web service that provides access to real-time USGS sensors. For more information about the service you can check out [this](https://labs.waterdata.usgs.gov/api-docs/about-sensorthings-api/index.html) to the service and also [this](https://waterdata.usgs.gov/blog/api_catalog/) which is overview or different USGS APIs. PyGeoHydro provides access to the `Things` endpoint which is "one of the most important components, and can be mapped to USGS Monitoring locations".

# %%
sensor = SensorThings()

# %% [markdown]
# We can query information about stations using `sensor_info`. We can pass a single ID or list of them.

# %%
resp = sensor.sensor_info(["USGS-09380000", "USGS-09472050"])
resp
# Out:
#   description        @iot.id           name properties.state  \
# 0      Stream  USGS-09380000  USGS-09380000          Arizona
# 1      Stream  USGS-09472050  USGS-09472050          Arizona
#
#    properties.active       properties.agency properties.county  \
# 0               True  U.S. Geological Survey   Coconino County
# 1               True  U.S. Geological Survey       Pima County
#
#   properties.country properties.district properties.stateFIPS  ...  \
# 0                 US             Arizona                US:04  ...
# 1                 US             Arizona                US:04  ...
#
#   properties.districtCode                  properties.altitudeDatum  \
# 0                      04     North American Vertical Datum of 1988
# 1                      04  National Geodetic Vertical Datum of 1929
#
#                    properties.altitudeMethod properties.hydrologicUnit  \
# 0  Interpolated from Digital Elevation Model              140700061105
# 1         Interpolated from topographic map.              150502030503
#
#   properties.altitudeAccuracy  \
# 0                         4.3
# 1                          10
#
#                     properties.monitoringLocationUrl  \
# 0  https://waterdata.usgs.gov/monitoring-location...
# 1  https://waterdata.usgs.gov/monitoring-location...
#
#                   properties.monitoringLocationName  \
# 0                  COLORADO RIVER AT LEES FERRY, AZ
# 1  SAN PEDRO R AT REDINGTON BRIDGE NR REDINGTON, AZ
#
#   properties.monitoringLocationType properties.monitoringLocationNumber  \
# 0                            Stream                            09380000
# 1                            Stream                            09472050
#
#   properties.monitoringLocationAltitudeLandSurface
# 0                                             3083
# 1                                            2820.
#
# [2 rows x 23 columns]

# %% [markdown]
# Additionally, we can get a sensor property using `sensor_property`.

# %%
resp = sensor.sensor_property("Datastreams", ["USGS-09380000", "USGS-09472050"])
resp
# Out:
#                                          description  \
# 0  Specific cond at 25C / USGS-09380000-9d24cf502...
# 1  None / USGS-09380000-0a10dcb7436f4af8a679a783a...
# 2  Discharge / USGS-09380000-a62122d8ff094125b63b...
# 3  Temperature, water / USGS-09380000-b3c374548a8...
# 4  None / USGS-09380000-e1c4b44914ed43819cf8e2e21...
# 5  None / USGS-09380000-c1d72c8390d144f78b51568a3...
# 6  Gage height / USGS-09472050-3c47927571274e388e...
# 7  Discharge / USGS-09472050-9e9527c7d6c542cd92a5...
#
#                             @iot.id                              name  \
# 0  9d24cf50257a4f60b76b92e38f286cde  9d24cf50257a4f60b76b92e38f286cde
# 1  0a10dcb7436f4af8a679a783ae3d8d58  0a10dcb7436f4af8a679a783ae3d8d58
# 2  a62122d8ff094125b63bb2f73410b2b4  a62122d8ff094125b63bb2f73410b2b4
# 3  b3c374548a8d4553868046dd9fda2582  b3c374548a8d4553868046dd9fda2582
# 4  e1c4b44914ed43819cf8e2e2138e9064  e1c4b44914ed43819cf8e2e2138e9064
# 5  c1d72c8390d144f78b51568a3755a5ad  c1d72c8390d144f78b51568a3755a5ad
# 6  3c47927571274e388e7f4a8fbf1049e9  3c47927571274e388e7f4a8fbf1049e9
# 7  9e9527c7d6c542cd92a5178922712ed8  9e9527c7d6c542cd92a5178922712ed8
#
#   observationType                                     phenomenonTime  \
# 0   Instantaneous  2021-07-12T18:45:00.000Z/2023-02-05T03:00:00.000Z
# 1   Instantaneous  2022-07-08T20:30:00.000Z/2022-07-20T19:00:00.000Z
# 2   Instantaneous  2021-09-16T11:00:00.000Z/2023-02-05T03:00:00.000Z
# 3   Instantaneous  2021-07-12T20:30:00.000Z/2023-02-05T03:00:00.000Z
# 4   Instantaneous  2022-01-10T01:30:00.000Z/2023-02-05T03:00:00.000Z
# 5   Instantaneous  2022-07-08T18:30:00.000Z/2023-02-05T03:00:00.000Z
# 6   Instantaneous  2021-07-16T22:45:00.000Z/2023-02-05T04:15:00.000Z
# 7   Instantaneous  2021-08-12T06:00:00.000Z/2023-02-05T04:15:00.000Z
#
#   resultTime                                      @iot.selfLink  \
# 0       None  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 1       None  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 2       None  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 3       None  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 4       None  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 5       None  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 6       None  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 7       None  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
#
#                  ObservedProperty@iot.navigationLink  \
# 0  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 1  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 2  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 3  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 4  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 5  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 6  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 7  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
#
#                            Sensor@iot.navigationLink  \
# 0  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 1  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 2  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 3  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 4  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 5  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 6  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 7  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
#
#                             Thing@iot.navigationLink  \
# 0  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 1  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 2  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 3  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 4  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 5  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 6  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
# 7  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...
#
#                      Observations@iot.navigationLink observedArea.type  \
# 0  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...             Point
# 1  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...             Point
# 2  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...             Point
# 3  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...             Point
# 4  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...             Point
# 5  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...             Point
# 6  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...             Point
# 7  https://labs.waterdata.usgs.gov/sta/v1.1/Datas...             Point
#
#      observedArea.coordinates  \
# 0  [-111.5878722, 36.8643333]
# 1  [-111.5878722, 36.8643333]
# 2  [-111.5878722, 36.8643333]
# 3  [-111.5878722, 36.8643333]
# 4  [-111.5878722, 36.8643333]
# 5  [-111.5878722, 36.8643333]
# 6  [-110.4884183, 32.4461827]
# 7  [-110.4884183, 32.4461827]
#
#                                properties.Thresholds properties.ParameterCode  \
# 0  [{'Name': 'HIGH SC THRESHOLD', 'Type': 'Thresh...                    00095
# 1                                                NaN                    00095
# 2                                                NaN                    00060
# 3                                                NaN                    00010
# 4                                                NaN                    00045
# 5                                                NaN                    00065
# 6  [{'Name': 'Operational limit (maximum) Upper l...                    00065
# 7                                                NaN                    00060
#
#   properties.StatisticCode unitOfMeasurement.name unitOfMeasurement.symbol  \
# 0                    00011                  uS/cm                    uS/cm
# 1                    00011                  uS/cm                    uS/cm
# 2                    00011  Cubic Feet per Second                   ft^3/s
# 3                    00011     Degrees Centigrade                     degC
# 4                      NaN                     in                       in
# 5                    00011                   Feet                       ft
# 6                    00011                   Feet                       ft
# 7                    00011  Cubic Feet per Second                   ft^3/s
#
#   unitOfMeasurement.definition properties.WebDescription
# 0                                                    NaN
# 1                                          Starts 7/8/22
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                          PRIMARY STAGE
# 6                                                    NaN
# 7                                                    NaN

# %% [markdown]
# For more complex queries, we need to construct an Odata query.

# %%
odata = {
    "filter": "properties/monitoringLocationType eq 'Stream' and properties/stateFIPS eq 'US:04'",
}
df = sensor.query_byodata(odata)
df
# Out:
#     description        @iot.id           name  \
# 0        Stream  USGS-09497700  USGS-09497700
# 1        Stream  USGS-09472050  USGS-09472050
# 2        Stream  USGS-09424900  USGS-09424900
# 3        Stream  USGS-09491980  USGS-09491980
# 4        Stream  USGS-09537200  USGS-09537200
# ..          ...            ...            ...
# 187      Stream  USGS-09403850  USGS-09403850
# 188      Stream  USGS-09429070  USGS-09429070
# 189      Stream  USGS-09402000  USGS-09402000
# 190      Stream  USGS-09535300  USGS-09535300
# 191      Stream  USGS-09415000  USGS-09415000
#
#                                          @iot.selfLink  \
# 0    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 1    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 2    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 3    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 4    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# ..                                                 ...
# 187  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 188  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 189  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 190  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 191  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
#
#                         Datastreams@iot.navigationLink  \
# 0    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 1    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 2    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 3    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 4    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# ..                                                 ...
# 187  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 188  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 189  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 190  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 191  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
#
#                 TaskingCapabilities@iot.navigationLink  \
# 0    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 1    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 2    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 3    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 4    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# ..                                                 ...
# 187  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 188  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 189  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 190  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 191  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
#
#                 HistoricalLocations@iot.navigationLink  \
# 0    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 1    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 2    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 3    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 4    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# ..                                                 ...
# 187  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 188  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 189  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 190  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 191  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
#
#                           Locations@iot.navigationLink  \
# 0    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 1    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 2    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 3    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 4    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# ..                                                 ...
# 187  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 188  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 189  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 190  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
# 191  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...
#
#                    MultiDatastreams@iot.navigationLink properties.state  ...  \
# 0    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...          Arizona  ...
# 1    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...          Arizona  ...
# 2    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...          Arizona  ...
# 3    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...          Arizona  ...
# 4    https://labs.waterdata.usgs.gov/sta/v1.1/Thing...          Arizona  ...
# ..                                                 ...              ...  ...
# 187  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...          Arizona  ...
# 188  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...          Arizona  ...
# 189  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...          Arizona  ...
# 190  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...          Arizona  ...
# 191  https://labs.waterdata.usgs.gov/sta/v1.1/Thing...          Arizona  ...
#
#      properties.districtCode                  properties.altitudeDatum  \
# 0                         04     North American Vertical Datum of 1988
# 1                         04  National Geodetic Vertical Datum of 1929
# 2                         04  National Geodetic Vertical Datum of 1929
# 3                         04     North American Vertical Datum of 1988
# 4                         04  National Geodetic Vertical Datum of 1929
# ..                       ...                                       ...
# 187                       04  National Geodetic Vertical Datum of 1929
# 188                       04     North American Vertical Datum of 1988
# 189                       04  National Geodetic Vertical Datum of 1929
# 190                       04  National Geodetic Vertical Datum of 1929
# 191                       32  National Geodetic Vertical Datum of 1929
#
#                      properties.altitudeMethod properties.hydrologicUnit  \
# 0           Interpolated from topographic map.              150601030102
# 1           Interpolated from topographic map.              150502030503
# 2           Interpolated from topographic map.              150302030506
# 3    Interpolated from Digital Elevation Model              150601020207
# 4           Interpolated from topographic map.              150803010307
# ..                                         ...                       ...
# 187         Interpolated from topographic map.              150100031004
# 188         Interpolated from topographic map.              150301040405
# 189                                   Unknown.              150200160906
# 190         Interpolated from topographic map.              150801010512
# 191            Level or other surveyed method.              150100100602
#
#     properties.altitudeAccuracy  \
# 0                            20
# 1                            10
# 2                            20
# 3                           1.6
# 4                            20
# ..                          ...
# 187                          20
# 188                          20
# 189                          20
# 190                          20
# 191                         1.0
#
#                       properties.monitoringLocationUrl  \
# 0    https://waterdata.usgs.gov/monitoring-location...
# 1    https://waterdata.usgs.gov/monitoring-location...
# 2    https://waterdata.usgs.gov/monitoring-location...
# 3    https://waterdata.usgs.gov/monitoring-location...
# 4    https://waterdata.usgs.gov/monitoring-location...
# ..                                                 ...
# 187  https://waterdata.usgs.gov/monitoring-location...
# 188  https://waterdata.usgs.gov/monitoring-location...
# 189  https://waterdata.usgs.gov/monitoring-location...
# 190  https://waterdata.usgs.gov/monitoring-location...
# 191  https://waterdata.usgs.gov/monitoring-location...
#
#                      properties.monitoringLocationName  \
# 0                     CIBECUE CREEK NEAR OVERGAARD, AZ
# 1     SAN PEDRO R AT REDINGTON BRIDGE NR REDINGTON, AZ
# 2                    SANTA MARIA RIVER NEAR BAGDAD, AZ
# 3    N-FORK WHITE RIVER BLW GOLD GULCH AT WHITERIVE...
# 4                        LESLIE CREEK NEAR MCNEAL, AZ.
# ..                                                 ...
# 187         KANAB CREEK ABOVE THE MOUTH NEAR SUPAI, AZ
# 188  CRIR LWR MAIN DRAIN BLW TYSON WW, NR EHRENBERG...
# 189             LITTLE COLORADO RIVER NEAR CAMERON, AZ
# 190                          VAMORI WASH AT KOM VO, AZ
# 191                       VIRGIN RV AT LITTLEFIELD, AZ
#
#     properties.monitoringLocationType properties.monitoringLocationNumber  \
# 0                              Stream                            09497700
# 1                              Stream                            09472050
# 2                              Stream                            09424900
# 3                              Stream                            09491980
# 4                              Stream                            09537200
# ..                                ...                                 ...
# 187                            Stream                            09403850
# 188                            Stream                            09429070
# 189                            Stream                            09402000
# 190                            Stream                            09535300
# 191                            Stream                            09415000
#
#     properties.monitoringLocationAltitudeLandSurface
# 0                                               7200
# 1                                              2820.
# 2                                               1360
# 3                                               5270
# 4                                              4620.
# ..                                               ...
# 187                                            1920.
# 188                                              272
# 189                                          3979.20
# 190                                            1770.
# 191                                          1763.68
#
# [192 rows x 29 columns]

# %% [markdown]
# We can get geospatial data by setting the format to `geojson`.

# %%
expand = {"Locations": {"select": "location"}}
max_count = 1000
conditionals = "properties/monitoringLocationType eq 'Stream' and properties/stateFIPS eq 'US:04'"
odata = sensor.odata_helper(expand=expand, max_count=max_count, conditionals=conditionals)

df = sensor.query_byodata(odata, outformat="geojson")
df.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29f0945ff3a8e5fbb3a028a35deffb65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29f0945ff3a8e5fbb3a028a35deffb65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29f0945ff3a8e5fbb3a028a35deffb65 = L.map(
#                 &quot;map_29f0945ff3a8e5fbb3a028a35deffb65&quot;,
#                 {
#                     center: [34.14358161111111, -111.9444167],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_29f0945ff3a8e5fbb3a028a35deffb65);
#
#
#
#
#
#             var tile_layer_5bd590fe88825bb54f048e0b772bf8db = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_29f0945ff3a8e5fbb3a028a35deffb65);
#
#
#             map_29f0945ff3a8e5fbb3a028a35deffb65.fitBounds(
#                 [[31.34327222222222, -114.7896667], [36.943891, -109.0991667]],
#                 {}
#             );
#
#
#         function geo_json_910762ef7fc2877898e2450168f34139_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_910762ef7fc2877898e2450168f34139_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_910762ef7fc2877898e2450168f34139_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_910762ef7fc2877898e2450168f34139_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_910762ef7fc2877898e2450168f34139_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_910762ef7fc2877898e2450168f34139.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_910762ef7fc2877898e2450168f34139_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_910762ef7fc2877898e2450168f34139 = L.geoJson(null, {
#                 onEachFeature: geo_json_910762ef7fc2877898e2450168f34139_onEachFeature,
#
#                 style: geo_json_910762ef7fc2877898e2450168f34139_styler,
#                 pointToLayer: geo_json_910762ef7fc2877898e2450168f34139_pointToLayer
#         });
#
#         function geo_json_910762ef7fc2877898e2450168f34139_add (data) {
#             geo_json_910762ef7fc2877898e2450168f34139
#                 .addData(data)
#                 .addTo(map_29f0945ff3a8e5fbb3a028a35deffb65);
#         }
#             geo_json_910762ef7fc2877898e2450168f34139_add({&quot;bbox&quot;: [-114.7896667, 31.34327222222222, -109.0991667, 36.943891], &quot;features&quot;: [{&quot;bbox&quot;: [-110.5111111111111, 34.157222222222224, -110.5111111111111, 34.157222222222224], &quot;geometry&quot;: {&quot;coordinates&quot;: [-110.5111111111111, 34.157222222222224], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;@iot.selfLink&quot;: &quot;https://labs.waterdata.usgs.gov/sta/v1.1/Things(\u0027USGS-09497700\u0027)&quot;, &quot;description&quot;: &quot;Stream&quot;, &quot;id&quot;: &quot;USGS-09497700&quot;, &quot;name&quot;: &quot;USGS-09497700&quot;, &quot;properties/active&quot;:

# %% [markdown]
# We can even make more complex queries. For such cases we can use the `odata_helper` function to contruct complex Odata filters.

# %%
expand = {
    "ObservedProperty": {"select": "name,description,@iot.id"},
    "Observations": {
        "select": "result,phenomenonTime,@iot.id",
        "orderby": "phenomenonTime desc",
        "top": 1,
    },
}
odata_inner = sensor.odata_helper(expand=expand)

columns = ["properties", "@iot.id"]
conditionals = " and ".join(
    [
        "Datastreams/ObservedProperty/@iot.id eq '00060' ",
        "properties/monitoringLocationType eq 'Stream' ",
        "startswith(properties/hydrologicUnit,'15')",
    ]
)
expand = {
    "Locations": {"select": "name,description,location,@iot.id"},
    "Datastreams": {
        "select": "name,unitOfMeasurement,@iot.id",
        "filter": "ObservedProperty/@iot.id eq '00060'",
        "expand": odata_inner["expand"],
    },
}
max_count = 1000
odata = sensor.odata_helper(
    columns=columns,
    conditionals=conditionals,
    expand=expand,
    max_count=max_count,
)

df = sensor.query_byodata(odata, outformat="geojson")
df.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd233a34eab806a40461730a488c1c3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd233a34eab806a40461730a488c1c3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd233a34eab806a40461730a488c1c3c = L.map(
#                 &quot;map_fd233a34eab806a40461730a488c1c3c&quot;,
#                 {
#                     center: [35.13830276111111, -111.7821986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_fd233a34eab806a40461730a488c1c3c);
#
#
#
#
#
#             var tile_layer_555a7d23d25b9763f1b2ae826a46d73e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fd233a34eab806a40461730a488c1c3c);
#
#
#             map_fd233a34eab806a40461730a488c1c3c.fitBounds(
#                 [[31.34327222222222, -115.3581194], [38.9333333, -108.2062778]],
#                 {}
#             );
#
#
#         function geo_json_8adb66b8e78544c43bbd87943a8f0ffa_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8adb66b8e78544c43bbd87943a8f0ffa_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8adb66b8e78544c43bbd87943a8f0ffa_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_8adb66b8e78544c43bbd87943a8f0ffa_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8adb66b8e78544c43bbd87943a8f0ffa_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_8adb66b8e78544c43bbd87943a8f0ffa.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8adb66b8e78544c43bbd87943a8f0ffa_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8adb66b8e78544c43bbd87943a8f0ffa = L.geoJson(null, {
#                 onEachFeature: geo_json_8adb66b8e78544c43bbd87943a8f0ffa_onEachFeature,
#
#                 style: geo_json_8adb66b8e78544c43bbd87943a8f0ffa_styler,
#                 pointToLayer: geo_json_8adb66b8e78544c43bbd87943a8f0ffa_pointToLayer
#         });
#
#         function geo_json_8adb66b8e78544c43bbd87943a8f0ffa_add (data) {
#             geo_json_8adb66b8e78544c43bbd87943a8f0ffa
#                 .addData(data)
#                 .addTo(map_fd233a34eab806a40461730a488c1c3c);
#         }
#             geo_json_8adb66b8e78544c43bbd87943a8f0ffa_add({&quot;bbox&quot;: [-115.3581194, 31.34327222222222, -108.2062778, 38.9333333], &quot;features&quot;: [{&quot;bbox&quot;: [-109.4573125, 34.0167143, -109.4573125, 34.0167143], &quot;geometry&quot;: {&quot;coordinates&quot;: [-109.4573125, 34.0167143], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Datastreams/0/Observations/0/id&quot;: &quot;ee7e6c3bd4da46129253785fe23a1d0f1675567800&quot;, &quot;Datastreams/0/Observations/0/phenomenonTime&quot;: &quot;2023-02-05T03:30:00.000Z&quot;, &quot;Datastreams/0/Observations/0/result&quot;: null, &quot;Datastreams/0/ObservedProperty/description&quot;: &quot;Physic
